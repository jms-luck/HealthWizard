# %%
import requests
import json

# %%
# Configure your Azure Maps subscription key here.
subscription_key = "EumXcWSYqKLcsw9zymB1cPRIfDzNbZBXO7BCjKsbsAITXSpRIZbMJQQJ99BBACYeBjFPDDZUAAAgAZMP1DsH"  # <-- Replace with your Azure Maps key. If left empty, the script will prompt for it.

def search_location(query, subscription_key):
    """Search for a location using Azure Maps Search API (Fuzzy Search)."""
    # Azure Maps Search (Fuzzy) endpoint URL
    base_url = "https://atlas.microsoft.com/search/fuzzy/json"
    params = {
        "api-version": "1.0",
        "subscription-key": subscription_key,
        "query": query
    }
    try:
        # Make the HTTP GET request to Azure Maps Search API
        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise HTTPError for bad responses (4xx/5xx)
    except requests.exceptions.RequestException as e:
        # Handle any network or HTTP errors
        print(f"Error during API request: {e}")
        return None

    # Parse the JSON response
    try:
        data = response.json()
    except ValueError:
        print("Error: Received response is not valid JSON.")
        return None

    return data

if __name__ == "__main__":
    # Prompt for subscription key if not provided
    if not subscription_key:
        subscription_key = input("Enter your Azure Maps subscription key: ").strip()
    if not subscription_key:
        print("No subscription key provided. Exiting.")
        exit(1)

    # Prompt user for a search query (location or address)
    query = input("Enter a location or address to search: ").strip()
    if not query:
        print("No search query provided. Exiting.")
        exit(1)

    # Perform the location search
    result_data = search_location(query, subscription_key)
    if result_data is None:
        # An error occurred during the API request; message already printed
        exit(1)

    # Print the full JSON result in a structured format
    print("\nFull JSON response:")
    print(json.dumps(result_data, indent=2))

    # Check if any results were returned
    results = result_data.get("results")
    if not results:
        print("\nNo results found for query:", query)
    else:
        # Display key details for each result
        print("\nSearch results:")
        for idx, res in enumerate(results, start=1):
            # Some results have a 'poi' field with the name for points of interest
            # If 'poi' is missing or has no name, use the freeform address as name
            name = None
            if "poi" in res and "name" in res["poi"]:
                name = res["poi"]["name"]
            elif "address" in res and "freeformAddress" in res["address"]:
                name = res["address"]["freeformAddress"]
            else:
                name = "(unknown name)"
            lat = res.get("position", {}).get("lat")
            lon = res.get("position", {}).get("lon")
            print(f"{idx}. Name: {name}")
            print(f"   Latitude: {lat}, Longitude: {lon}")
# Out:
# Full JSON response:
# {
#   "summary": {
#     "query": "chennai",
#     "queryType": "NON_NEAR",
#     "queryTime": 168,
#     "numResults": 10,
#     "offset": 0,
#     "totalResults": 100,
#     "fuzzyLevel": 1,
#     "queryIntent": []
#   },
#   "results": [
#     {
#       "type": "Geography",
#       "id": "1yaftj4CvhUs_NsIJjnAZg",
#       "score": 2.872004509,
#       "entityType": "Municipality",
#       "address": {
#         "municipality": "Chennai",
#         "countrySecondarySubdivision": "Chennai",
#         "countrySubdivision": "Tamil Nadu",
#         "countrySubdivisionName": "Tamil Nadu",
#         "countrySubdivisionCode": "TN",
#         "countryCode": "IN",
#         "country": "India",
#         "countryCodeISO3": "IND",
#         "freeformAddress": "Chennai, Tamil Nadu"
#       },
#       "position": {
#         "lat": 13.072092,
#         "lon": 80.201855
#       },
#       "viewport": {
#         "topLeftPoint": {
#           "lat": 13.23403,
#           "lon": 79.97689
#         },
#         "btmRightPoint": {
#           "lat": 12.85071,
#           "lon": 80.33293
#         }
#       },
#       "boundingBox": {
#         "topLeftPoint": {
#           "lat": 13.234028,
#           "lon": 79.976895
#         },
#         "btmRightPoint": {
#           "lat": 12.850707,
#           "lon": 80.332925
#         }
#       },
#       "dataSources": {
#         "geometry": {
#           "id": "8945c434-2bfb-469d-a39e-af4f8b1f68e2"
#         }
#       }
#     },
#     {
#       "type": "POI",
#       "id": "N5BvMYk2F_eXynFOOg0n4g",
#       "score": 2.3913753033,
#       "info": "search:ta:356009013216967-IN",
#       "poi": {
#         "name": "Chennai International Airport Terminal 4 Departure",
#         "categorySet": [
#           {
#             "id": 7389002
#           }
#         ],
#         "categories": [
#           "access gateway",
#           "airline access"
#         ],
#         "classifications": [
#           {
#             "code": "ACCESS_GATEWAY",
#             "names": [
#               {
#                 "nameLocale": "en-US",
#                 "name": "airline access"
#               },
#               {
#                 "nameLocale": "en-US",
#                 "name": "access gateway"
#               }
#             ]
#           }
#         ]
#       },
#       "address": {
#         "municipalitySubdivision": "Meenambakkam",
#         "municipality": "Chennai",
#         "municipalitySecondarySubdivision": "Chennai International Airport",
#         "countrySecondarySubdivision": "Chennai",
#         "countrySubdivision": "Tamil Nadu",
#         "countrySubdivisionName": "Tamil Nadu",
#         "countrySubdivisionCode": "TN",
#         "postalCode": "601213",
#         "countryCode": "IN",
#         "country": "India",
#         "countryCodeISO3": "IND",
#         "freeformAddress": "Chennai International Airport, Meenambakkam, Chennai 601213, Tamil Nadu",
#         "localName": "Chennai"
#       },
#       "position": {
#         "lat": 12.982291,
#         "lon": 80.163112
#       },
#       "viewport": {
#         "topLeftPoint": {
#           "lat": 12.9863,
#           "lon": 80.159
#         },
#         "btmRightPoint": {
#           "lat": 12.97828,
#           "lon": 80.16723
#         }
#       },
#       "entryPoints": [
#         {
#           "type": "minor",
#           "position": {
#             "lat": 12.98176,
#             "lon": 80.16327
#           }
#         },
#         {
#           "type": "main",
#           "position": {
#             "lat": 12.98311,
#             "lon": 80.16714
#           }
#         }
#       ]
#     },
#     {
#       "type": "POI",
#       "id": "bPJPDKtl_sk55GIAsv6efg",
#       "score": 2.3913753033,
#       "info": "search:ta:356009013236029-IN",
#       "poi": {
#         "name": "Chennai International Airport Terminal 3 Arrival",
#         "categorySet": [
#           {
#             "id": 7389002
#           }
#         ],
#         "categories": [
#           "access gateway",
#           "airline access"
#         ],
#         "classifications": [
#           {
#             "code": "ACCESS_GATEWAY",
#             "names": [
#               {
#                 "nameLocale": "en-US",
#                 "name": "airline access"
#               },
#               {
#                 "nameLocale": "en-US",
#                 "name": "access gateway"
#               }
#             ]
#           }
#         ]
#       },
#       "address": {
#         "municipalitySubdivision": "Meenambakkam",
#         "municipality": "Chennai",
#         "municipalitySecondarySubdivision": "Chennai International Airport",
#         "countrySecondarySubdivision": "Chennai",
#         "countrySubdivision": "Tamil Nadu",
#         "countrySubdivisionName": "Tamil Nadu",
#         "countrySubdivisionCode": "TN",
#         "postalCode": "601213",
#         "countryCode": "IN",
#         "country": "India",
#         "countryCodeISO3": "IND",
#         "freeformAddress": "Chennai International Airport, Meenambakkam, Chennai 601213, Tamil Nadu",
#         "localName": "Chennai"
#       },
#       "position": {
#         "lat": 12.981893,
#         "lon": 80.16184
#       },
#       "viewport": {
#         "topLeftPoint": {
#           "lat": 12.9872,
#           "lon": 80.15639
#         },
#         "btmRightPoint": {
#           "lat": 12.97659,
#           "lon": 80.16729
#         }
#       },
#       "entryPoints": [
#         {
#           "type": "minor",
#           "position": {
#             "lat": 12.98129,
#             "lon": 80.16205
#           }
#         },
#         {
#           "type": "main",
#           "position": {
#             "lat": 12.98311,
#             "lon": 80.16714
#           }
#         }
#       ]
#     },
#     {
#       "type": "POI",
#       "id": "cu362W9SvSiptpMFTOjf5g",
#       "score": 2.1239202023,
#       "info": "search:ta:356009013245408-IN",
#       "poi": {
#         "name": "Chennai International Airport",
#         "categorySet": [
#           {
#             "id": 7383002
#           }
#         ],
#         "categories": [
#           "airport",
#           "public authority"
#         ],
#         "classifications": [
#           {
#             "code": "AIRPORT",
#             "names": [
#               {
#                 "nameLocale": "en-US",
#                 "name": "airport"
#               },
#               {
#                 "nameLocale": "en-US",
#                 "name": "public authority"
#               }
#             ]
#           }
#         ]
#       },
#       "address": {
#         "municipalitySubdivision": "Meenambakkam",
#         "municipality": "Chennai",
#         "municipalitySecondarySubdivision": "Chennai International Airport",
#         "countrySecondarySubdivision": "Chennai",
#         "countrySubdivision": "Tamil Nadu",
#         "countrySubdivisionName": "Tamil Nadu",
#         "countrySubdivisionCode": "TN",
#         "postalCode": "601213",
#         "countryCode": "IN",
#         "country": "India",
#         "countryCodeISO3": "IND",
#         "freeformAddress": "Chennai International Airport, Meenambakkam, Chennai 601213, Tamil Nadu",
#         "localName": "Chennai"
#       },
#       "position": {
#         "lat": 12.982608,
#         "lon": 80.163506
#       },
#       "viewport": {
#         "topLeftPoint": {
#           "lat": 13.00845,
#           "lon": 80.14514
#         },
#         "btmRightPoint": {
#           "lat": 12.98053,
#           "lon": 80.1895
#         }
#       },
#       "entryPoints": [
#         {
#           "type": "minor",
#           "position": {
#             "lat": 12.9879,
#             "lon": 80.17463
#           }
#         },
#         {
#           "type": "minor",
#           "position": {
#             "lat": 12.98174,
#             "lon": 80.16322
#           }
#         },
#         {
#           "type": "minor",
#           "position": {
#             "lat": 12.98129,
#             "lon": 80.16205
#           }
#         },
#         {
#           "type": "minor",
#           "position": {
#             "lat": 12.98146,
#             "lon": 80.16281
#           }
#         },
#         {
#           "type": "minor",
#           "position": {
#             "lat": 12.98176,
#             "lon": 80.16327
#           }
#         },
#         {
#           "type": "main",
#           "position": {
#             "lat": 12.98314,
#             "lon": 80.16708
#           }
#         },
#         {
#           "type": "main",
#           "position": {
#             "lat": 12.98311,
#             "lon": 80.16714
#           }
#         }
#       ],
#       "dataSources": {
#         "geometry": {
#           "id": "00004e31-3800-3c00-0000-00005be910a4"
#         }
#       }
#     },
#     {
#       "type": "Geography",
#       "id": "bkZuImwj1nhOZW-m4dT68w",
#       "score": 2.1199998856,
#       "entityType": "CountrySecondarySubdivision",
#       "address": {
#         "countrySecondarySubdivision": "Chennai",
#         "countrySubdivision": "Tamil Nadu",
#         "countrySubdivisionName": "Tamil Nadu",
#         "countrySubdivisionCode": "TN",
#         "countryCode": "IN",
#         "country": "India",
#         "countryCodeISO3": "IND",
#         "freeformAddress": "Chennai, Tamil Nadu"
#       },
#       "position": {
#         "lat": 13.072092,
#         "lon": 80.201855
#       },
#       "viewport": {
#         "topLeftPoint": {
#           "lat": 13.23403,
#           "lon": 79.97689
#         },
#         "btmRightPoint": {
#           "lat": 12.85071,
#           "lon": 80.33293
#         }
#       },
#       "boundingBox": {
#         "topLeftPoint": {
#           "lat": 13.234028,
#           "lon": 79.976895
#         },
#         "btmRightPoint": {
#           "lat": 12.850707,
#           "lon": 80.332925
#         }
#       },
#       "dataSources": {
#         "geometry": {
#           "id": "a5224c5c-ffc9-4755-935a-bc124543d640"
#         }
#       }
#     },
#     {
#       "type": "POI",
#       "id": "9EFJBxjA15RaepF7vlT5wg",
#       "score": 2.1037807465,
#       "info": "search:ta:356002006053227-IN",
#       "poi": {
#         "name": "Chennai Light House",
#         "categorySet": [
#           {
#             "id": 7376002
#           }
#         ],
#         "categories": [
#           "building",
#           "important tourist attraction"
#         ],
#         "classifications": [
#           {
#             "code": "IMPORTANT_TOURIST_ATTRACTION",
#             "names": [
#               {
#                 "nameLocale": "en-US",
#                 "name": "building"
#               },
#               {
#                 "nameLocale": "en-US",
#                 "name": "important tourist attraction"
#               }
#             ]
#           }
#         ]
#       },
#       "address": {
#         "streetName": "Kamarajar Salai",
#         "municipalitySubdivision": "Mylapore",
#         "municipality": "Chennai",
#         "municipalitySecondarySubdivision": "Nachi Kuppam",
#         "countrySecondarySubdivision": "Chennai",
#         "countrySubdivision": "Tamil Nadu",
#         "countrySubdivisionName": "Tamil Nadu",
#         "countrySubdivisionCode": "TN",
#         "postalCode": "600004",
#         "countryCode": "IN",
#         "country": "India",
#         "countryCodeISO3": "IND",
#         "freeformAddress": "Kamarajar Salai, Nachi Kuppam, Mylapore, Chennai 600004, Tamil Nadu",
#         "localName": "Chennai"
#       },
#       "position": {
#         "lat": 13.039693,
#         "lon": 80.279312
#       },
#       "viewport": {
#         "topLeftPoint": {
#           "lat": 13.04059,
#           "lon": 80.27839
#         },
#         "btmRightPoint": {
#           "lat": 13.03879,
#           "lon": 80.28024
#         }
#       },
#       "entryPoints": [
#         {
#           "type": "main",
#           "position": {
#             "lat": 13.0402,
#             "lon": 80.27979
#           }
#         }
#       ]
#     },
#     {
#       "type": "POI",
#       "id": "hjGZvhu5-IEa_7IrW8GiiQ",
#       "score": 2.1037807465,
#       "info": "search:ta:356002006053230-IN",
#       "poi": {
#         "name": "Chennai Crocodile Bank",
#         "categorySet": [
#           {
#             "id": 7376
#           }
#         ],
#         "categories": [
#           "important tourist attraction"
#         ],
#         "classifications": [
#           {
#             "code": "IMPORTANT_TOURIST_ATTRACTION",
#             "names": [
#               {
#                 "nameLocale": "en-US",
#                 "name": "important tourist attraction"
#               }
#             ]
#           }
#         ]
#       },
#       "address": {
#         "streetName": "East Coast Road",
#         "municipalitySubdivision": "Nemmeli",
#         "municipality": "Thiruporur",
#         "countrySecondarySubdivision": "Chengalpattu",
#         "countrySubdivision": "Tamil Nadu",
#         "countrySubdivisionName": "Tamil Nadu",
#         "countrySubdivisionCode": "TN",
#         "postalCode": "603104",
#         "countryCode": "IN",
#         "country": "India",
#         "countryCodeISO3": "IND",
#         "freeformAddress": "East Coast Road, Nemmeli, Thiruporur 603104, Tamil Nadu",
#         "localName": "Thiruporur"
#       },
#       "position": {
#         "lat": 12.743224,
#         "lon": 80.238853
#       },
#       "viewport": {
#         "topLeftPoint": {
#           "lat": 12.74412,
#           "lon": 80.23793
#         },
#         "btmRightPoint": {
#           "lat": 12.74232,
#           "lon": 80.23978
#         }
#       },
#       "entryPoints": [
#         {
#           "type": "main",
#           "position": {
#             "lat": 12.74325,
#             "lon": 80.23816
#           }
#         }
#       ]
#     },
#     {
#       "type": "POI",
#       "id": "nmrmesaD_M0NnhIV6Ay03w",
#       "score": 2.1037807465,
#       "info": "search:ta:356009032795841-IN",
#       "poi": {
#         "name": "Chennai Corporation Building",
#         "categorySet": [
#           {
#             "id": 7376002
#           }
#         ],
#         "categories": [
#           "building",
#           "important tourist attraction"
#         ],
#         "classifications": [
#           {
#             "code": "IMPORTANT_TOURIST_ATTRACTION",
#             "names": [
#               {
#                 "nameLocale": "en-US",
#                 "name": "building"
#               },
#               {
#                 "nameLocale": "en-US",
#                 "name": "important tourist attraction"
#               }
#             ]
#           }
#         ]
#       },
#       "address": {
#         "streetName": "Raja Muthiah Road, Central Metro Station, Periamet",
#         "municipalitySubdivision": "Pulianthope",
#         "municipality": "Chennai",
#         "municipalitySecondarySubdivision": "Kannappar Thidal",
#         "countrySecondarySubdivision": "Chennai",
#         "countrySubdivision": "Tamil Nadu",
#         "countrySubdivisionName": "Tamil Nadu",
#         "countrySubdivisionCode": "TN",
#         "postalCode": "600003",
#         "countryCode": "IN",
#         "country": "India",
#         "countryCodeISO3": "IND",
#         "freeformAddress": "Raja Muthiah Road, Central Metro Station, Periamet, Kannappar Thidal, Pulianthope, Chennai 600003, Tamil Nadu",
#         "localName": "Chennai"
#       },
#       "position": {
#         "lat": 13.081239,
#         "lon": 80.271412
#       },
#       "viewport": {
#         "topLeftPoint": {
#           "lat": 13.08214,
#           "lon": 80.27049
#         },
#         "btmRightPoint": {
#           "lat": 13.08034,
#           "lon": 80.27234
#         }
#       },
#       "entryPoints": [
#         {
#           "type": "main",
#           "position": {
#             "lat": 13.08124,
#             "lon": 80.27151
#           }
#         }
#       ]
#     },
#     {
#       "type": "POI",
#       "id": "L90EPieOr4QLJvd0-Ph-dw",
#       "score": 2.1037807465,
#       "info": "search:ta:356007000581960-IN",
#       "poi": {
#         "name": "Chennai Gurudwara Sahib",
#         "categorySet": [
#           {
#             "id": 7376
#           }
#         ],
#         "url": "www.facebook.com/ChennaiGurudwara/",
#         "categories": [
#           "important tourist attraction"
#         ],
#         "classifications": [
#           {
#             "code": "IMPORTANT_TOURIST_ATTRACTION",
#             "names": [
#               {
#                 "nameLocale": "en-US",
#                 "name": "important tourist attraction"
#               }
#             ]
#           }
#         ]
#       },
#       "address": {
#         "streetName": "Gn Chetty Road",
#         "municipalitySubdivision": "Thyagaraya Nagar",
#         "municipality": "Chennai",
#         "municipalitySecondarySubdivision": "Satyamurthy Nagar",
#         "countrySecondarySubdivision": "Chennai",
#         "countrySubdivision": "Tamil Nadu",
#         "countrySubdivisionName": "Tamil Nadu",
#         "countrySubdivisionCode": "TN",
#         "postalCode": "600017",
#         "countryCode": "IN",
#         "country": "India",
#         "countryCodeISO3": "IND",
#         "freeformAddress": "Gn Chetty Road, Satyamurthy Nagar, Thyagaraya Nagar, Chennai 600017, Tamil Nadu",
#         "localName": "Chennai"
#       },
#       "position": {
#         "lat": 13.04741,
#         "lon": 80.24377
#       },
#       "viewport": {
#         "topLeftPoint": {
#           "lat": 13.04831,
#           "lon": 80.24285
#         },
#         "btmRightPoint": {
#           "lat": 13.04651,
#           "lon": 80.24469
#         }
#       },
#       "entryPoints": [
#         {
#           "type": "main",
#           "position": {
#             "lat": 13.04701,
#             "lon": 80.24299
#           }
#         }
#       ]
#     },
#     {
#       "type": "Street",
#       "id": "VwAbHxVjOnFj1YE7WPpuqA",
#       "score": 2.0962057114,
#       "address": {
#         "streetName": "Chennai Road",
#         "municipality": "Thottambedu",
#         "countrySecondarySubdivision": "Tirupati",
#         "countrySubdivision": "Andhra Pradesh",
#         "countrySubdivisionName": "Andhra Pradesh",
#         "countrySubdivisionCode": "AP",
#         "countryCode": "IN",
#         "country": "India",
#         "countryCodeISO3": "IND",
#         "freeformAddress": "Chennai Road, Thottambedu, Andhra Pradesh",
#         "localName": "Thottambedu"
#       },
#       "position": {
#         "lat": 13.749078,
#         "lon": 79.709432
#       },
#       "viewport": {
#         "topLeftPoint": {
#           "lat": 13.75824,
#           "lon": 79.70059
#         },
#         "btmRightPoint": {
#           "lat": 13.74026,
#           "lon": 79.71911
#         }
#       }
#     }
#   ]
# }
#
# Search results:
# 1. Name: Chennai, Tamil Nadu
#    Latitude: 13.072092, Longitude: 80.201855
# 2. Name: Chennai International Airport Terminal 4 Departure
#    Latitude: 12.982291, Longitude: 80.163112
# 3. Name: Chennai International Airport Terminal 3 Arrival
#    Latitude: 12.981893, Longitude: 80.16184
# 4. Name: Chennai International Airport
#    Latitude: 12.982608, Longitude: 80.163506
# 5. Name: Chennai, Tamil Nadu
#    Latitude: 13.072092, Longitude: 80.201855
# 6. Name: Chennai Light House
#    Latitude: 13.039693, Longitude: 80.279312
# 7. Name: Chennai Crocodile Bank
#    Latitude: 12.743224, Longitude: 80.238853
# 8. Name: Chennai Corporation Building
#    Latitude: 13.081239, Longitude: 80.271412
# 9. Name: Chennai Gurudwara Sahib
#    Latitude: 13.04741, Longitude: 80.24377
# 10. Name: Chennai Road, Thottambedu, Andhra Pradesh
#    Latitude: 13.749078, Longitude: 79.709432
